# %%
from importlib import reload
import src.hakanmath
reload(src.hakanmath);

# %%
x = src.hakanmath.Rational(2,3)
y = src.hakanmath.Rational(4,5)

# %%
x, y
# Out:
# (2/3, 4/5)

# %%
x + y
# Out:
# 22/15

# %%
x - y
# Out:
# -2/15

# %%
x * y
# Out:
# 8/15

# %%
x.reduce()
# Out:
# 2/3
